# %% [markdown]
# <a href="https://colab.research.google.com/github/Pedro0Oliveira/PythonPHBO/blob/main/Atividade_6_questao_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Input/Output: Conversor de Temperatura

# %%
def coversor():
  Celsius = float(input("Digite a temperatura em graus celsius: "))
  Fahrenheit = Celsius * 9/5 + 32
  print("A temperatura, convertida em celsius, é: ", Fahrenheit)
