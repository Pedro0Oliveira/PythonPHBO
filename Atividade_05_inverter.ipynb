# %% [markdown]
# <a href="https://colab.research.google.com/github/Pedro0Oliveira/PythonPHBO/blob/main/Atividade_05_inverter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def inverter_string(s):
  string = s
  string_invertida = string[::-1]
  return string_invertida
