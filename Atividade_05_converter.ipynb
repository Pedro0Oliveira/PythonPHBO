# %% [markdown]
# <a href="https://colab.research.google.com/github/Pedro0Oliveira/PythonPHBO/blob/main/Atividade_05_converter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def converter_para_maiusculas(arquivo_entrada, arquivo_saida):
  arquivo_entrada = ['flamengo']
  while arquivo_entrada == 'flamengo':
    arquivo_saida == arquivo_entrada.upper()
