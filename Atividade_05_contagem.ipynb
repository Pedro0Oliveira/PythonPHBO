# %% [markdown]
# <a href="https://colab.research.google.com/github/Pedro0Oliveira/PythonPHBO/blob/main/Atividade_05_contagem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def contar_palavra(arquivo, palavra):
  palavra = 'lobo'
  arquivo = ['lobo', 'lobo', 'cajú', 'acerola', 'beijos', 'beijos']

  return int(arquivo.count(palavra))

arquivo = ['lobo', 'lobo', 'cajú', 'acerola', 'beijos', 'beijos']
palavra = 'lobo'
print(contar_palavra(arquivo, palavra))
# Out:
# 2
