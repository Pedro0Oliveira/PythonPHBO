# %% [markdown]
# <a href="https://colab.research.google.com/github/Pedro0Oliveira/PythonPHBO/blob/main/11_N%C3%BAmeros_Aleatorios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

print(random.randint(1, 100))
# Out:
# 69

# %%
alunos = ['Daniel', 'Joao', 'Beatriz', 'Maria']
print(random.choice(alunos))
print(random.choice(alunos))
print(random.choice(alunos))
# Out:
# Daniel
# Maria
# Beatriz

# %%
alunos = ['Daniel', 'Joao', 'Beatriz', 'Maria']
print(alunos)
random.shuffle(alunos)
print(alunos)
# Out:
# ['Daniel', 'Joao', 'Beatriz', 'Maria']
# ['Beatriz', 'Daniel', 'Joao', 'Maria']

# %% [markdown]
# #Função para embaralhar letras de uma palavra

# %%
def embaralha(palavra):
  lista = list(palavra)
  random.shuffle(lista)
  return ''.join(lista)

palavra = embaralha('programacao')
print(palavra)
# Out:
# roracpaamog
