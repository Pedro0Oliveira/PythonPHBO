# %% [markdown]
# <a href="https://colab.research.google.com/github/Pedro0Oliveira/PythonPHBO/blob/main/Atividade_6_questao_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Matriz Bidimensional: Soma de Matrizes

# %%
def matrizes(m1, m2):
  r = [[0,0], [0,0]]
  for i in range(2):
    for j in range(2):
      r = m1[i][j] + m2[i][j]
  return r
