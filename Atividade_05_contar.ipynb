# %% [markdown]
# <a href="https://colab.research.google.com/github/Pedro0Oliveira/PythonPHBO/blob/main/Atividade_05_contar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def contar_caracteres(s):
  caracteres = {}
  for n in s:
    if n in caracteres:
      caracteres[n] += 1
    else:
      caracteres[n] = 1
  return caracteres
print(contar_caracteres("Aloha"))
# Out:
# {'A': 1, 'l': 1, 'o': 1, 'h': 1, 'a': 1}
